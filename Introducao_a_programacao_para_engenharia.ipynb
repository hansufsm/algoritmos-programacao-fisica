# %% [markdown]
# # 🥇 DESAFIO PRÁTICA - Implemente os exercícios propostos nos capítulos do livro
# ### **✍ Início:** _17/10/2023_
# ### **⏰ Duração:** Entregar até uma semana antes do final do Semestre
#
# ---

# %% [markdown]
# # Exercícios Cap 2
#
# _2.7, 2.9, 2.9, 2.10 e 2.11_

# %% [markdown]
# # Exercícios Cap 3
# *3.1, 3.2, 3.3, 3.4, 3.5 e 3.6*

# %%
x = int(input("Digite um valor para x:"))
x
# Out:
# 45

# %% [markdown]
# # Exercícios Cap 4
# *4.3, 4.4, 4.5,4.6, 4.7,4.8, 4.9 e 4.10*

# %% [markdown]
# # Exercícios Cap 5
# *5.4*

# %% [markdown]
# # Exercícios Cap 8
# *8.1, 8.2, 8.3, 8.4, 8.5 e 8.6*
